# %% [markdown]
# # Netflix Data Analysis

# %%
import pandas as pd
data = pd.read_csv(r"C:\Users\acer\Downloads\netflix_data.csv")

# %%
data
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating   duration  \
# 0     United States   9/25/2021          2020  PG-13     90 min
# 1            France   9/24/2021          2021  TV-MA   1 Season
# 2     United States   9/24/2021          2021  TV-MA   1 Season
# 3            Brazil   9/22/2021          2021  TV-PG     91 min
# 4     United States   9/24/2021          1993  TV-MA    125 min
# ...             ...         ...           ...    ...        ...
# 8785         Turkey   1/17/2017          2016  TV-PG  2 Seasons
# 8786  United States   9/13/2018          2016  TV-Y7  3 Seasons
# 8787       Pakistan  12/15/2016          2012  TV-PG   1 Season
# 8788       Pakistan   6/23/2018          2016   TV-Y   1 Season
# 8789       Pakistan  06/07/2018          2016  TV-Y7   1 Season
#
#                                               listed_in
# 0                                         Documentaries
# 1     Crime TV Shows, International TV Shows, TV Act...
# 2                    TV Dramas, TV Horror, TV Mysteries
# 3                    Children & Family Movies, Comedies
# 4      Dramas, Independent Movies, International Movies
# ...                                                 ...
# 8785                  International TV Shows, TV Dramas
# 8786                                           Kids' TV
# 8787  International TV Shows, Romantic TV Shows, TV ...
# 8788                                           Kids' TV
# 8789                                           Kids' TV
#
# [8790 rows x 10 columns]

# %% [markdown]
# ####  Top 5 records of the dataset

# %%
data.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States  9/25/2021          2020  PG-13    90 min
# 1         France  9/24/2021          2021  TV-MA  1 Season
# 2  United States  9/24/2021          2021  TV-MA  1 Season
# 3         Brazil  9/22/2021          2021  TV-PG    91 min
# 4  United States  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# 2                 TV Dramas, TV Horror, TV Mysteries
# 3                 Children & Family Movies, Comedies
# 4   Dramas, Independent Movies, International Movies

# %% [markdown]
# ### Bottom 5 datasets of table

# %%
data.tail()
# Out:
#      show_id     type               title   director        country  \
# 8785   s8797  TV Show          Yunus Emre  Not Given         Turkey
# 8786   s8798  TV Show           Zak Storm  Not Given  United States
# 8787   s8801  TV Show  Zindagi Gulzar Hai  Not Given       Pakistan
# 8788   s8784  TV Show                Yoko  Not Given       Pakistan
# 8789   s8786  TV Show                 YOM  Not Given       Pakistan
#
#       date_added  release_year rating   duration  \
# 8785   1/17/2017          2016  TV-PG  2 Seasons
# 8786   9/13/2018          2016  TV-Y7  3 Seasons
# 8787  12/15/2016          2012  TV-PG   1 Season
# 8788   6/23/2018          2016   TV-Y   1 Season
# 8789  06/07/2018          2016  TV-Y7   1 Season
#
#                                               listed_in
# 8785                  International TV Shows, TV Dramas
# 8786                                           Kids' TV
# 8787  International TV Shows, Romantic TV Shows, TV ...
# 8788                                           Kids' TV
# 8789                                           Kids' TV

# %% [markdown]
# #### Total number of rows and columns

# %%
data.shape
# Out:
# (8790, 10)

# %% [markdown]
# #### Total number of values

# %%
data.size
# Out:
# 87900

# %% [markdown]
# ####  Show each column's name

# %% [markdown]
# #### Show the data type of each column

# %%
data.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# dtype: object

# %% [markdown]
# ##### Null values

# %%
data.isnull()
# Out:
#       show_id   type  title  director  country  date_added  release_year  \
# 0       False  False  False     False    False       False         False
# 1       False  False  False     False    False       False         False
# 2       False  False  False     False    False       False         False
# 3       False  False  False     False    False       False         False
# 4       False  False  False     False    False       False         False
# ...       ...    ...    ...       ...      ...         ...           ...
# 8785    False  False  False     False    False       False         False
# 8786    False  False  False     False    False       False         False
# 8787    False  False  False     False    False       False         False
# 8788    False  False  False     False    False       False         False
# 8789    False  False  False     False    False       False         False
#
#       rating  duration  listed_in
# 0      False     False      False
# 1      False     False      False
# 2      False     False      False
# 3      False     False      False
# 4      False     False      False
# ...      ...       ...        ...
# 8785   False     False      False
# 8786   False     False      False
# 8787   False     False      False
# 8788   False     False      False
# 8789   False     False      False
#
# [8790 rows x 10 columns]

# %%
data.isnull().sum() #count of null values in each column
# Out:
# show_id         0
# type            0
# title           0
# director        0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %%
# percentage of movies = no.of movies / length of df * 100. Values are then rounded 

percentage_movies  = round(len(data[data['type'] == 'Movie']) / len(data) *100, 2)
percentage_movies
# Out:
# 69.69

# %% [markdown]
# ###### 69.69% of the content type in the Netflix dataset are movies.

# %%
# No. of unique directors in the dataset

data['director'].nunique()
# Out:
# 4528

# %%
data['director'].value_counts()
# Out:
# director
# Not Given                         2588
# Rajiv Chilaka                       20
# Alastair Fothergill                 18
# Raúl Campos, Jan Suter              18
# Suhas Kadav                         16
#                                   ...
# Matt D'Avella                        1
# Parthiban                            1
# Scott McAboy                         1
# Raymie Muzquiz, Stu Livingston       1
# Mozez Singh                          1
# Name: count, Length: 4528, dtype: int64

# %%
# show first 3 movies directed by Rajiv Chilaka. 

data[data['director'] == 'Rajiv Chilaka'].head(3)
# Out:
#     show_id   type                          title       director country  \
# 511    s420  Movie  Chhota Bheem: Bheem vs Aliens  Rajiv Chilaka   India
# 561    s407  Movie   Chhota Bheem - Neeli Pahaadi  Rajiv Chilaka   India
# 562    s408  Movie          Chhota Bheem & Ganesh  Rajiv Chilaka   India
#
#     date_added  release_year rating duration  \
# 511  7/22/2021          2010  TV-Y7   69 min
# 561  7/22/2021          2013  TV-Y7   64 min
# 562  7/22/2021          2009  TV-Y7   68 min
#
#                                    listed_in
# 511  Children & Family Movies, Sports Movies
# 561                 Children & Family Movies
# 562                 Children & Family Movies

# %%
# show the rows with missing directors.

data[data['director'] == 'Not Given']
# Out:
#      show_id     type                            title   director  \
# 12      s852    Movie                 99 Songs (Tamil)  Not Given
# 17        s4  TV Show            Jailbirds New Orleans  Not Given
# 18       s15  TV Show  Crime Stories: India Detectives  Not Given
# 33       s20  TV Show                           Jaguar  Not Given
# 34       s32  TV Show               Chicago Party Aunt  Not Given
# ...      ...      ...                              ...        ...
# 8785   s8797  TV Show                       Yunus Emre  Not Given
# 8786   s8798  TV Show                        Zak Storm  Not Given
# 8787   s8801  TV Show               Zindagi Gulzar Hai  Not Given
# 8788   s8784  TV Show                             Yoko  Not Given
# 8789   s8786  TV Show                              YOM  Not Given
#
#             country  date_added  release_year rating   duration  \
# 12         Pakistan   5/21/2021          2021  TV-14    131 min
# 17         Pakistan   9/24/2021          2021  TV-MA   1 Season
# 18         Pakistan   9/22/2021          2021  TV-MA   1 Season
# 33         Pakistan   9/22/2021          2021  TV-MA   1 Season
# 34         Pakistan   9/17/2021          2021  TV-MA   1 Season
# ...             ...         ...           ...    ...        ...
# 8785         Turkey   1/17/2017          2016  TV-PG  2 Seasons
# 8786  United States   9/13/2018          2016  TV-Y7  3 Seasons
# 8787       Pakistan  12/15/2016          2012  TV-PG   1 Season
# 8788       Pakistan   6/23/2018          2016   TV-Y   1 Season
# 8789       Pakistan  06/07/2018          2016  TV-Y7   1 Season
#
#                                               listed_in
# 12       Dramas, International Movies, Music & Musicals
# 17                               Docuseries, Reality TV
# 18         British TV Shows, Crime TV Shows, Docuseries
# 33    International TV Shows, Spanish-Language TV Sh...
# 34                                          TV Comedies
# ...                                                 ...
# 8785                  International TV Shows, TV Dramas
# 8786                                           Kids' TV
# 8787  International TV Shows, Romantic TV Shows, TV ...
# 8788                                           Kids' TV
# 8789                                           Kids' TV
#
# [2588 rows x 10 columns]

# %%
# Calculate percentage of missing directors

director_null_values  = round(len(data[data['director'] == 'Not Given']) / len(data) *100, 2)
director_null_values
# Out:
# 29.44

# %%
data['country'].value_counts().head(10)
# Out:
# country
# United States     3240
# India             1057
# United Kingdom     638
# Pakistan           421
# Not Given          287
# Canada             271
# Japan              259
# South Korea        214
# France             213
# Spain              182
# Name: count, dtype: int64

# %% [markdown]
# ###### Majority of the content was produced in the USA (3240), followed by India (1057) and UK (638).

# %% [markdown]
# ### Adding Date column

# %%
data[['date_added']].head(10)
# Out:
#    date_added
# 0   9/25/2021
# 1   9/24/2021
# 2   9/24/2021
# 3   9/22/2021
# 4   9/24/2021
# 5   9/24/2021
# 6   9/24/2021
# 7  05/01/2021
# 8   9/23/2021
# 9  05/01/2021

# %%
# convert the column to datetime and show first 5 rows.

data['date_added'] = pd.to_datetime(data['date_added'])
data['date_added'].head()
# Out:
# 0   2021-09-25
# 1   2021-09-24
# 2   2021-09-24
# 3   2021-09-22
# 4   2021-09-24
# Name: date_added, dtype: datetime64[ns]

# %%
data[['date_added']].describe()
# Out:
#                           date_added
# count                           8790
# mean   2019-05-17 21:44:01.638225408
# min              2008-01-01 00:00:00
# 25%              2018-04-06 00:00:00
# 50%              2019-07-03 00:00:00
# 75%              2020-08-19 18:00:00
# max              2021-09-25 00:00:00

# %% [markdown]
# - count: number of content added to the streaming platform is 8790.
# - mean year that content was added is 2019.
# - The minimum number of content added was 2008.
# - 25% of content was added between 2008 and 2018.
# - 50% of content was added before 2019 and 50% was added after 2019.
# - 75% of content was added from 2008 and 2020.
# - The maximum number of content was added in 2021.
# - The content is generally added to the platform at midnight.

# %% [markdown]
# #### Longest Movie ?

# %%
data[data['type'] == 'Movie']['duration'].max()
# Out:
# '99 min'

# %%
data['listed_in'].value_counts()
# Out:
# listed_in
# Dramas, International Movies                                362
# Documentaries                                               359
# Stand-Up Comedy                                             334
# Comedies, Dramas, International Movies                      274
# Dramas, Independent Movies, International Movies            252
#                                                            ...
# Anime Features                                                1
# Action & Adventure, Horror Movies, Independent Movies         1
# Action & Adventure, Classic Movies, International Movies      1
# Cult Movies, Independent Movies, Thrillers                    1
# Classic & Cult TV, Crime TV Shows, TV Dramas                  1
# Name: count, Length: 513, dtype: int64

# %% [markdown]
# ###### majority of the content in the data set is based on Dramas, Documentaries and Comedy.

# %% [markdown]
# ## Data Manipulation and Cleaning

# %% [markdown]
# - Apply functions to column and set show_id as index
# - remove duplicate titles (3)
# - convert 'not given' to unknown for 'country' and 'director' columns
# - convert column data types

# %% [markdown]
# ### Apply function to 'show_id' and set as the Index

# %%
data.index
# Out:
# RangeIndex(start=0, stop=8790, step=1)

# %%
# define a function that takes a value and returns all characters after the first character 's'.
# Return as an integer

def remove_s(x):
    return int(x[1:])

# %%
# replace the 'show_id' column with function, apply to the column.

data['show_id'] = data['show_id'].apply(remove_s)

# %%
# 's' has been renived from the column.

data.head()
# Out:
#    show_id     type                             title         director  \
# 0        1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1        3  TV Show                         Ganglands  Julien Leclercq
# 2        6  TV Show                     Midnight Mass    Mike Flanagan
# 3       14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4        8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States 2021-09-25          2020  PG-13    90 min
# 1         France 2021-09-24          2021  TV-MA  1 Season
# 2  United States 2021-09-24          2021  TV-MA  1 Season
# 3         Brazil 2021-09-22          2021  TV-PG    91 min
# 4  United States 2021-09-24          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# 2                 TV Dramas, TV Horror, TV Mysteries
# 3                 Children & Family Movies, Comedies
# 4   Dramas, Independent Movies, International Movies

# %%
# set show_id as the index and save to original data frame

data.set_index(['show_id'], inplace=True)

# %%
data
# Out:
#             type                             title         director  \
# show_id
# 1          Movie              Dick Johnson Is Dead  Kirsten Johnson
# 3        TV Show                         Ganglands  Julien Leclercq
# 6        TV Show                     Midnight Mass    Mike Flanagan
# 14         Movie  Confessions of an Invisible Girl    Bruno Garotti
# 8          Movie                           Sankofa     Haile Gerima
# ...          ...                               ...              ...
# 8797     TV Show                        Yunus Emre        Not Given
# 8798     TV Show                         Zak Storm        Not Given
# 8801     TV Show                Zindagi Gulzar Hai        Not Given
# 8784     TV Show                              Yoko        Not Given
# 8786     TV Show                               YOM        Not Given
#
#                country date_added  release_year rating   duration  \
# show_id
# 1        United States 2021-09-25          2020  PG-13     90 min
# 3               France 2021-09-24          2021  TV-MA   1 Season
# 6        United States 2021-09-24          2021  TV-MA   1 Season
# 14              Brazil 2021-09-22          2021  TV-PG     91 min
# 8        United States 2021-09-24          1993  TV-MA    125 min
# ...                ...        ...           ...    ...        ...
# 8797            Turkey 2017-01-17          2016  TV-PG  2 Seasons
# 8798     United States 2018-09-13          2016  TV-Y7  3 Seasons
# 8801          Pakistan 2016-12-15          2012  TV-PG   1 Season
# 8784          Pakistan 2018-06-23          2016   TV-Y   1 Season
# 8786          Pakistan 2018-06-07          2016  TV-Y7   1 Season
#
#                                                  listed_in
# show_id
# 1                                            Documentaries
# 3        Crime TV Shows, International TV Shows, TV Act...
# 6                       TV Dramas, TV Horror, TV Mysteries
# 14                      Children & Family Movies, Comedies
# 8         Dramas, Independent Movies, International Movies
# ...                                                    ...
# 8797                     International TV Shows, TV Dramas
# 8798                                              Kids' TV
# 8801     International TV Shows, Romantic TV Shows, TV ...
# 8784                                              Kids' TV
# 8786                                              Kids' TV
#
# [8790 rows x 9 columns]

# %% [markdown]
# ## Remove Duplicate Rows

# %%
data.drop_duplicates(inplace=True)

# %%
data
# Out:
#             type                             title         director  \
# show_id
# 1          Movie              Dick Johnson Is Dead  Kirsten Johnson
# 3        TV Show                         Ganglands  Julien Leclercq
# 6        TV Show                     Midnight Mass    Mike Flanagan
# 14         Movie  Confessions of an Invisible Girl    Bruno Garotti
# 8          Movie                           Sankofa     Haile Gerima
# ...          ...                               ...              ...
# 8797     TV Show                        Yunus Emre        Not Given
# 8798     TV Show                         Zak Storm        Not Given
# 8801     TV Show                Zindagi Gulzar Hai        Not Given
# 8784     TV Show                              Yoko        Not Given
# 8786     TV Show                               YOM        Not Given
#
#                country date_added  release_year rating   duration  \
# show_id
# 1        United States 2021-09-25          2020  PG-13     90 min
# 3               France 2021-09-24          2021  TV-MA   1 Season
# 6        United States 2021-09-24          2021  TV-MA   1 Season
# 14              Brazil 2021-09-22          2021  TV-PG     91 min
# 8        United States 2021-09-24          1993  TV-MA    125 min
# ...                ...        ...           ...    ...        ...
# 8797            Turkey 2017-01-17          2016  TV-PG  2 Seasons
# 8798     United States 2018-09-13          2016  TV-Y7  3 Seasons
# 8801          Pakistan 2016-12-15          2012  TV-PG   1 Season
# 8784          Pakistan 2018-06-23          2016   TV-Y   1 Season
# 8786          Pakistan 2018-06-07          2016  TV-Y7   1 Season
#
#                                                  listed_in
# show_id
# 1                                            Documentaries
# 3        Crime TV Shows, International TV Shows, TV Act...
# 6                       TV Dramas, TV Horror, TV Mysteries
# 14                      Children & Family Movies, Comedies
# 8         Dramas, Independent Movies, International Movies
# ...                                                    ...
# 8797                     International TV Shows, TV Dramas
# 8798                                              Kids' TV
# 8801     International TV Shows, Romantic TV Shows, TV ...
# 8784                                              Kids' TV
# 8786                                              Kids' TV
#
# [8787 rows x 9 columns]

# %% [markdown]
# ## Dealing with 'Not Given' values

# %%
data['director'].value_counts()
# Out:
# director
# Not Given                         2587
# Rajiv Chilaka                       20
# Raúl Campos, Jan Suter              18
# Alastair Fothergill                 18
# Marcus Raboy                        16
#                                   ...
# Parthiban                            1
# Scott McAboy                         1
# Raymie Muzquiz, Stu Livingston       1
# Joe Menendez                         1
# Mozez Singh                          1
# Name: count, Length: 4528, dtype: int64

# %% [markdown]
# ###### There are 2587 not given values

# %%
# replace the duplicates in dataframe, from old to new value, and save to original dataframe

data.replace(to_replace='Not Given', value= 'Unknown', inplace=True)

# %%
# All of the old values in 'director' column has been removed 

data[data['director'] == 'Not Given']
# Out:
# Empty DataFrame
# Columns: [type, title, director, country, date_added, release_year, rating, duration, listed_in]
# Index: []

# %% [markdown]
# ## Netflix Content Type Overview

# %%
data['type'].value_counts().plot(kind='bar', title='Frequency of TV shows and movies');

# %% [markdown]
# ## Top countries contributing to the content on Netflix

# %%
data['country'].unique()
# Out:
# array(['United States', 'France', 'Brazil', 'United Kingdom', 'India',
#        'Germany', 'Pakistan', 'Unknown', 'China', 'South Africa', 'Japan',
#        'Nigeria', 'Spain', 'Philippines', 'Australia', 'Argentina',
#        'Canada', 'Hong Kong', 'Italy', 'New Zealand', 'Egypt', 'Colombia',
#        'Mexico', 'Belgium', 'Switzerland', 'Taiwan', 'Bulgaria', 'Poland',
#        'South Korea', 'Saudi Arabia', 'Thailand', 'Indonesia', 'Kuwait',
#        'Malaysia', 'Vietnam', 'Lebanon', 'Romania', 'Syria',
#        'United Arab Emirates', 'Sweden', 'Mauritius', 'Austria', 'Turkey',
#        'Czech Republic', 'Cameroon', 'Netherlands', 'Ireland', 'Russia',
#        'Kenya', 'Chile', 'Uruguay', 'Bangladesh', 'Portugal', 'Hungary',
#        'Norway', 'Singapore', 'Iceland', 'Serbia', 'Namibia', 'Peru',
#        'Mozambique', 'Ghana', 'Zimbabwe', 'Israel', 'Finland', 'Denmark',
#        'Paraguay', 'Cambodia', 'Georgia', 'Soviet Union', 'Greece',
#        'West Germany', 'Iran', 'Venezuela', 'Slovenia', 'Guatemala',
#        'Jamaica', 'Somalia', 'Croatia', 'Jordan', 'Luxembourg', 'Senegal',
#        'Belarus', 'Puerto Rico', 'Cyprus', 'Ukraine'], dtype=object)

# %%
# Top 10 countries producing content, excluding 'Unknown' countries.

top_10_countries = data['country'].value_counts().head(11).drop('Unknown')
top_10_countries
# Out:
# country
# United States     3240
# India             1056
# United Kingdom     638
# Pakistan           420
# Canada             271
# Japan              259
# South Korea        214
# France             213
# Spain              182
# Mexico             138
# Name: count, dtype: int64

# %%
top_10_countries.plot(kind='barh', title='Top 10 content producing countries');

# %% [markdown]
# ## Diversity of Movie content on Netflix

# %%
cntr_movies = data[data['country'] != 'Unknown'].groupby([
    'type'])['country'].value_counts().head(10)

cntr_movies
# Out:
# type   country
# Movie  United States     2395
#        India              975
#        United Kingdom     387
#        Canada             187
#        France             148
#        Spain              129
#        Egypt              109
#        Nigeria             96
#        Mexico              90
#        Japan               87
# Name: count, dtype: int64

# %%
cntr_movies.unstack().sort_values(
    by='type').plot(kind='bar', title='Top Ten Countries for Movie Production');

# %% [markdown]
# ##### Neflix is streaming movies predominantly produced in the USA.

# %%
# US movie contribution as a percentage 
movies_united_states = data[data['type'] == 'Movie'][['country']].value_counts().iloc[0]
total_movies = len(data[data['type'] == 'Movie'])
movie_industry_us = round((movies_united_states / total_movies) * 100, 2)
movie_industry_us
# Out:
# 39.11

# %% [markdown]
# ## Diversity of TV content on Netflix

# %%
tvshow = data[data['type'] == 'TV Show']
tvshow.head()
# Out:
#             type                            title         director  \
# show_id
# 3        TV Show                        Ganglands  Julien Leclercq
# 6        TV Show                    Midnight Mass    Mike Flanagan
# 9        TV Show    The Great British Baking Show  Andy Devonshire
# 4        TV Show            Jailbirds New Orleans          Unknown
# 15       TV Show  Crime Stories: India Detectives          Unknown
#
#                 country date_added  release_year rating   duration  \
# show_id
# 3                France 2021-09-24          2021  TV-MA   1 Season
# 6         United States 2021-09-24          2021  TV-MA   1 Season
# 9        United Kingdom 2021-09-24          2021  TV-14  9 Seasons
# 4              Pakistan 2021-09-24          2021  TV-MA   1 Season
# 15             Pakistan 2021-09-22          2021  TV-MA   1 Season
#
#                                                  listed_in
# show_id
# 3        Crime TV Shows, International TV Shows, TV Act...
# 6                       TV Dramas, TV Horror, TV Mysteries
# 9                             British TV Shows, Reality TV
# 4                                   Docuseries, Reality TV
# 15            British TV Shows, Crime TV Shows, Docuseries

# %%
countries_tvshows_top10 = tvshow['country'].value_counts()[0:10]
countries_tvshows_top10
# Out:
# country
# United States     845
# Pakistan          349
# United Kingdom    251
# Japan             172
# South Korea       165
# Canada             84
# India              81
# Taiwan             71
# France             65
# Australia          53
# Name: count, dtype: int64

# %%
countries_tvshows_top10.plot(kind='barh', title='Top Ten Countries for TV Show Production');

# %% [markdown]
# ##### US, Pakistan and UK are the top three contributors.

# %% [markdown]
# ## Popularity

# %%
data['listed_in'].nunique()
# Out:
# 513

# %%
data['listed_in'].value_counts().head(10)
# Out:
# listed_in
# Dramas, International Movies                        362
# Documentaries                                       359
# Stand-Up Comedy                                     334
# Comedies, Dramas, International Movies              274
# Dramas, Independent Movies, International Movies    252
# Kids' TV                                            219
# Children & Family Movies                            215
# Children & Family Movies, Comedies                  201
# Documentaries, International Movies                 186
# Dramas, International Movies, Romantic Movies       180
# Name: count, dtype: int64

# %%
# list the top ten genres

top_10_genre = data['listed_in'].str.split(',').explode().value_counts().head(10)
top_10_genre
# Out:
# listed_in
#  International Movies     2624
# Dramas                    1598
# Comedies                  1209
# Action & Adventure         859
# Documentaries              829
#  Dramas                    826
# International TV Shows     772
#  Independent Movies        735
#  TV Dramas                 694
#  Romantic Movies           613
# Name: count, dtype: int64

# %%
import seaborn as sn

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(14, 8))
sn.barplot(y=top_10_genre.index, x=top_10_genre.values, hue=top_10_genre.index, palette='dark', legend=False)
plt.title('Netflix: Top 10 Genres')
plt.xlabel('Number of Titles')
plt.ylabel('Genre')
plt.show()

# %% [markdown]
# ###### International movies take the lead with 2624 titles, this reflects the high number of content produced in India as well as the Hispanic countries and Phillipines.

# %%
top_10_directors = data['director'].value_counts().drop('Unknown').head(10)
top_10_directors
# Out:
# director
# Rajiv Chilaka             20
# Raúl Campos, Jan Suter    18
# Alastair Fothergill       18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Jay Chapman               12
# Youssef Chahine           12
# Name: count, dtype: int64

# %%
sn.barplot(y=top_10_directors.index, x=top_10_directors.values, hue=top_10_directors.index, palette='flare', legend=False)
plt.title('Netflix: Top 10 Directors')
plt.xlabel('Number of Titles')
plt.ylabel('Director')
plt.show()

# %%
# perform statistical calculations on the 'ratings' column,  using .agg() method
rating = data.groupby(['type'])['rating'].value_counts().to_frame()

rating.groupby('rating')[['count']].agg(['sum', 'max', 'mean', 'min', 'std'])
# Out:
#          count
#            sum   max    mean   min         std
# rating
# G           41    41    41.0    41         NaN
# NC-17        3     3     3.0     3         NaN
# NR          79    75    39.5     4   50.204581
# PG         287   287   287.0   287         NaN
# PG-13      490   490   490.0   490         NaN
# R          798   796   399.0     2  561.442784
# TV-14     2155  1426  1077.5   729  492.853426
# TV-G       220   126   110.0    94   22.627417
# TV-MA     3205  2062  1602.5  1143  649.831132
# TV-PG      861   540   430.5   321  154.856385
# TV-Y       306   175   153.0   131   31.112698
# TV-Y7      333   194   166.5   139   38.890873
# TV-Y7-FV     6     5     3.0     1    2.828427
# UR           3     3     3.0     3         NaN

# %%
rating.groupby('rating')[['count']].agg(['sum', 'max', 'mean', 'min', 'std'])
# Out:
#          count
#            sum   max    mean   min         std
# rating
# G           41    41    41.0    41         NaN
# NC-17        3     3     3.0     3         NaN
# NR          79    75    39.5     4   50.204581
# PG         287   287   287.0   287         NaN
# PG-13      490   490   490.0   490         NaN
# R          798   796   399.0     2  561.442784
# TV-14     2155  1426  1077.5   729  492.853426
# TV-G       220   126   110.0    94   22.627417
# TV-MA     3205  2062  1602.5  1143  649.831132
# TV-PG      861   540   430.5   321  154.856385
# TV-Y       306   175   153.0   131   31.112698
# TV-Y7      333   194   166.5   139   38.890873
# TV-Y7-FV     6     5     3.0     1    2.828427
# UR           3     3     3.0     3         NaN

# %%
plt.figure(figsize=(12, 8))
sn.countplot(x='rating', hue='type', data=data, order=data['rating'].value_counts().index, palette='Set1')
plt.title('TV Show Ratings vs Movie Ratings')
plt.xlabel('Ratings')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Type')
plt.show()

# %%
# Countplot for Type vs Rating

plt.figure(figsize=(12, 8))
sn.histplot(x='rating', hue='type', data=data, multiple='layer', palette='Set1', kde=True)
plt.title('TV Show Ratings vs Movie Ratings')
plt.xlabel('Ratings')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
# Countplot for Top 10 'release years'.

plt.figure(figsize=(10, 6))
sn.countplot(data=data, x='release_year', order=data['release_year'].value_counts().iloc[:10].index)
plt.title('Top 10 Most Frequent Release Years')
plt.xlabel('Release Year')
plt.ylabel('Count')
plt.show()
